# %%
import numpy as np

# %% [markdown]
# (a) Mean, standard deviation and variance along second axis

# %%
arr2d = np.random.randint(1, 100, (4, 5))
print("2D Array:\n", arr2d)
print("Mean:", np.mean(arr2d, axis=1))
print("Standard Deviation:", np.std(arr2d, axis=1))
print("Variance:", np.var(arr2d, axis=1))

# %% [markdown]
# (b) Create m x n array and reshape to n x m

# %%
m = int(input("Enter m: "))
n = int(input("Enter n: "))

arr = np.random.randint(1, 50, (m, n))
print("\nOriginal Array:\n", arr)
print("Shape:", arr.shape)
print("Type:", type(arr))
print("Data Type:", arr.dtype)

reshaped_arr = arr.reshape(n, m)
print("Reshaped Array:\n", reshaped_arr)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 m = int(input("Enter m: "))
#       2 n = int(input("Enter n: "))
#       4 arr = np.random.randint(1, 50, (m, n))
#
# File /opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
#    1264     self._parent_ident["shell"],
#    1265     self.get_parent("shell"),
#    1266     password=False,
#    1267 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py:1305, in Kernel._input_request(self, prompt, ident, parent, password)
#    1302 except KeyboardInterrupt:
# ...

# %% [markdown]
# (c) Check zero, non-zero and NaN elements

# %%
arr1d = np.array([0, 4, np.nan, 7, 0, 9, np.nan])
print("\n1D Array:", arr1d)

zero_indices = np.where(arr1d == 0)
nonzero_indices = np.where(arr1d != 0)
nan_indices = np.where(np.isnan(arr1d))

print("Zero indices:", zero_indices)
print("Non-zero indices:", nonzero_indices)
print("NaN indices:", nan_indices)

# %% [markdown]
# (d) Covariance and Correlation

# %%
Array1 = np.random.rand(10)
Array2 = np.random.rand(10)
Array3 = np.random.rand(10)

Array4 = Array3 - Array2
Array5 = 2 * Array1

print("\nArray1:", Array1)
print("Array4:", Array4)
print("Array5:", Array5)

print("Covariance:\n", np.cov(Array1, Array4))
print("Correlation:\n", np.corrcoef(Array1, Array5))

# %% [markdown]
# (e) Sum of first half and product of second half

# %%
Array1 = np.random.randint(1, 10, 10)
Array2 = np.random.randint(1, 10, 10)

print("\nArray1:", Array1)
print("Array2:", Array2)

print("Sum of first half:", Array1[:5] + Array2[:5])
print("Product of second half:", Array1[5:] * Array2[5:])
