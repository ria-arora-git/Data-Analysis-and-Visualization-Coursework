# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("weight-height.csv")

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
Q1 = df.Weight.quantile(0.25)
Q3 = df.Weight.quantile(0.75)

IQR = Q3-Q1
print(IQR)
# Out:
# 51.35147356318197

# %%
lower_limit = Q1-1.5*IQR
upper_limit = Q3+1.5*IQR
print(lower_limit, upper_limit)
# Out:
# 58.79084096072856 264.19673521345646

# %%
df.Weight.describe()
# Out:
# count    10000.000000
# mean       161.440357
# std         32.108439
# min         64.700127
# 25%        135.818051
# 50%        161.212928
# 75%        187.169525
# max        269.989699
# Name: Weight, dtype: float64

# %%
plt.boxplot(df.Weight)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1526c7290>,
#   <matplotlib.lines.Line2D at 0x1526c7560>],
#  'caps': [<matplotlib.lines.Line2D at 0x1526c76b0>,
#   <matplotlib.lines.Line2D at 0x1526c7980>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1525f3ef0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1526c7c20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1526c7ef0>],
#  'means': []}

# %%
outlier=df[(df.Weight<lower_limit)|(df.Weight>upper_limit)]

# %%
df_no_outliers=df[(df.Weight>lower_limit)&(df.Weight<upper_limit)]

# %%
plt.boxplot(df_no_outliers.Weight)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x166d562a0>,
#   <matplotlib.lines.Line2D at 0x166d565a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x166d56870>,
#   <matplotlib.lines.Line2D at 0x166d56b10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x166d54c20>],
#  'medians': [<matplotlib.lines.Line2D at 0x166d56db0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x166d57080>],
#  'means': []}
