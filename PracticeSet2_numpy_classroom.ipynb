# %% [markdown]
# SECTION A

# %%
import numpy as np

arr = np.array([10, 20, 30, 40, 50, 60, 70])
arr
# Out:
# array([10, 20, 30, 40, 50, 60, 70])

# %%
arr[[0,2,4,6]]
# Out:
# array([10, 30, 50, 70])

# %%
arr[[1,4,6]]
# Out:
# array([20, 50, 70])

# %%
arr[::-1]
# Out:
# array([70, 60, 50, 40, 30, 20, 10])

# %%
arr[[1,3,5]] = 0
arr
# Out:
# array([10,  0, 30,  0, 50,  0, 70])

# %%
arr[arr>30]
# Out:
# array([50, 70])

# %% [markdown]
# SECTION B

# %%
arr = np.array([12,45,67,23,89,10,55])

# %%
arr[arr>50]
# Out:
# array([67, 89, 55])

# %%
arr[arr<20] = -1

# %%
count = np.sum((arr >= 20) & (arr <= 60))
count
# Out:
# 3

# %%
arr[arr % 2 == 0]
# Out:
# array([12, 10])

# %%
arr[arr > 40] ** 2
# Out:
# array([2025, 4489, 7921, 3025])

# %% [markdown]
# SECTION C

# %%
arr = np.array([[10, 20, 30],
                [40, 50, 60],
                [70, 80, 90]])
arr
# Out:
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90]])

# %%
arr[[0, 1, 2], [0, 1, 2]]
# Out:
# array([10, 50, 90])

# %%
arr[[0, 1, 2], [2, 1, 0]]
# Out:
# array([30, 50, 70])

# %%
arr[[0, 2]]
# Out:
# array([[10, 20, 30],
#        [70, 80, 90]])

# %%
arr[:, [1, 2]]
# Out:
# array([[20, 30],
#        [50, 60],
#        [80, 90]])

# %%
arr[arr < 40] = 0
arr
# Out:
# array([[ 0,  0,  0],
#        [40, 50, 60],
#        [70, 80, 90]])

# %% [markdown]
# SECTION D

# %%
arr = np.arange(24).reshape(2, 3, 4)
arr.shape
# Out:
# (2, 3, 4)

# %%
t1 = arr.transpose(1, 0, 2)
t1
t1.shape
# Out:
# (3, 2, 4)

# %%
t2 = arr.transpose(2, 1, 0)
t2
t2.shape
# Out:
# (4, 3, 2)

# %%
swapped = arr.swapaxes(0, 1)
swapped.shape
# Out:
# (3, 2, 4)
